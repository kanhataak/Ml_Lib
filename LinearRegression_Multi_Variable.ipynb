# %% [markdown]
# # MultiVariable_LinearRegression

# %% [markdown]
# The goal of multiple linear regression (MLR) is to model the linear relationship between the explanatory (independent) variables and response (dependent) variable.
#
# In essence, multiple regression is the extension of ordinary least-squares (OLS) regressionthat involves more than one explanatory variable.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\MR.INDIA\Desktop\Machine Learning\DataSets\homeprices.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df.bedrooms.median()
# Out:
# 4.0

# %%
df.bedrooms.fillna(df.bedrooms.median())
# Out:
# 0    3.0
# 1    4.0
# 2    4.0
# 3    3.0
# 4    5.0
# 5    6.0
# Name: bedrooms, dtype: float64

# %%
df.bedrooms=df.bedrooms.fillna(df.bedrooms.median())
df
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000
# 5  4100       6.0    8  810000

# %%
df.hist(bins=30, figsize=(10,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0FBBA530>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10C459D0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10C65A70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10C86B50>]],
#       dtype=object)

# %%
plt.scatter(df.area,df.age)
plt.xlabel("Area")
plt.ylabel('Age')
# Out:
# Text(0, 0.5, 'Age')

# %%
plt.scatter(df.area,df.price)
plt.xlabel("AREA")
plt.ylabel('PRICE')
# Out:
# Text(0, 0.5, 'PRICE')

# %%
import seaborn as sn
sn.pairplot(df)

# %%
sn.pairplot(df,diag_kind="kde")

# %%
sn.pairplot(df,diag_kind="kde",kind="reg")

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(df[["area","bedrooms",'age']],df.price)  # Model
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.predict([[1200,3,5]])
# Out:
# array([409805.98288662])

# %%
reg.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
reg.intercept_
# Out:
# 221323.00186540408

# %%
reg.score(df[['area','bedrooms',"age"]],df.price)
# Out:
# 0.955019639932582

# %% [markdown]
# # PRACTICES

# %%
df1=pd.read_csv(r"C:\Users\MR.INDIA\Desktop\Machine Learning\DataSets\hirings.csv")
df1
# Out:
#   experience  test_score  interview_score  salary
# 0        NaN         8.0                9   50000
# 1        NaN         8.0                6   45000
# 2       five         6.0                7   60000
# 3        two        10.0               10   65000
# 4      seven         9.0                6   70000
# 5      three         7.0               10   62000
# 6        ten         NaN                7   72000
# 7     eleven         7.0                8   80000

# %%
df1.experience.fillna("zero")
# Out:
# 0      zero
# 1      zero
# 2      five
# 3       two
# 4     seven
# 5     three
# 6       ten
# 7    eleven
# Name: experience, dtype: object

# %%
df1.experience=df1.experience.fillna('zero')
df1
# Out:
#   experience  test_score  interview_score  salary
# 0       zero         8.0                9   50000
# 1       zero         8.0                6   45000
# 2       five         6.0                7   60000
# 3        two        10.0               10   65000
# 4      seven         9.0                6   70000
# 5      three         7.0               10   62000
# 6        ten         NaN                7   72000
# 7     eleven         7.0                8   80000

# %%
#pip install word2number
# import sys
# !{sys.executable} -m pip install word2number

# %%
from word2number import w2n
df1.experience = df1.experience.apply(w2n.word_to_num)

# %%
df1
# Out:
#    experience  test_score  interview_score  salary
# 0           0         8.0                9   50000
# 1           0         8.0                6   45000
# 2           5         6.0                7   60000
# 3           2        10.0               10   65000
# 4           7         9.0                6   70000
# 5           3         7.0               10   62000
# 6          10         NaN                7   72000
# 7          11         7.0                8   80000

# %%
df1.test_score.median()
# Out:
# 8.0

# %%
df1.test_score.fillna(df1.test_score.median())
# Out:
# 0     8.0
# 1     8.0
# 2     6.0
# 3    10.0
# 4     9.0
# 5     7.0
# 6     8.0
# 7     7.0
# Name: test_score, dtype: float64

# %%
df1.test_score = df1.test_score.fillna(df1.test_score.median())

# %%
df1
# Out:
#    experience  test_score  interview_score  salary
# 0           0         8.0                9   50000
# 1           0         8.0                6   45000
# 2           5         6.0                7   60000
# 3           2        10.0               10   65000
# 4           7         9.0                6   70000
# 5           3         7.0               10   62000
# 6          10         8.0                7   72000
# 7          11         7.0                8   80000

# %%
sn.pairplot(df1)

# %%
sn.pairplot(df1,diag_kind="kde")

# %%
sn.pairplot(df1,diag_kind="kde",kind='reg')

# %%
df1.hist(bins=30, figsize=(10,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x20CF9B50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x20CC2290>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x2056EF30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x20FD9CF0>]],
#       dtype=object)

# %%
sn.pairplot(df1)

# %%
reg1=LinearRegression()
reg1.fit(df1[["experience",'test_score','interview_score']],df1.salary)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg1.coef_
# Out:
# array([2812.95487627, 1845.70596798, 2205.24017467])

# %%
reg1.intercept_
# Out:
# 17737.26346433768

# %%
reg1.predict([[5,6,9]])
# Out:
# array([62723.43522562])

# %%
reg1.predict([[7,7,9]])
# Out:
# array([70195.05094614])

# %%
reg1.score(df1[["experience",'test_score','interview_score']],df1.salary)
# Out:
# 0.9616780002577959

# %%
df1
# Out:
#    experience  test_score  interview_score  salary
# 0           0         8.0                9   50000
# 1           0         8.0                6   45000
# 2           5         6.0                7   60000
# 3           2        10.0               10   65000
# 4           7         9.0                6   70000
# 5           3         7.0               10   62000
# 6          10         8.0                7   72000
# 7          11         7.0                8   80000

# %%
df1.hist(bins=35,figsize=(11,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x21717D50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x218BA910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x009D49F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x009F2A90>]],
#       dtype=object)
