# %% [markdown]
# # Univariate,Bivariate and MultiVariate Analysis
# https://www.statisticshowto.com/univariate/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-e493b6b70efc> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4 import seaborn as sn
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\__init__.py in <module>
#     205
#     206
# --> 207 _check_versions()
#     208
#     209
#
# ~\AppData\Roaming\Python\Python37\site-packages\matplotlib\__init__.py in _check_versions()
#     190     # Quickfix to ensure Microsoft Visual C++ redistributable
#     191     # DLLs are loaded before importing kiwisolver
# --> 192     from . import ft2font
#     193
#     194     for modname, minver in [
#
# ImportError: cannot import name 'ft2font' from 'matplotlib' (C:\Users\MR.INDIA\AppData\Roaming\Python\Python37\site-packages\matplotlib\__init__.py)

# %%
data = pd.read_csv(r"C:\Users\MR.INDIA\Desktop\Machine Learning\DataSets\iris.csv")
data[50:55]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     variety
# 50           7.0          3.2           4.7          1.4  Versicolor
# 51           6.4          3.2           4.5          1.5  Versicolor
# 52           6.9          3.1           4.9          1.5  Versicolor
# 53           5.5          2.3           4.0          1.3  Versicolor
# 54           6.5          2.8           4.6          1.5  Versicolor

# %%
data.shape
# Out:
# (150, 5)

# %%
data.count()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# variety         150
# dtype: int64

# %%
data.size
# Out:
# 750

# %% [markdown]
# # Univariate Analysis
# * This type of data consists of only one variable. The analysis of univariate data is thus the simplest form of analysis since the information deals with only one quantity that changes. It does not deal with causes or relationships and the main purpose of the analysis is to describe the data and find patterns that exist within it. The example

# %%
data_setosa = data.loc[data["variety"]=='Setosa']

# %%
data_versicolor= data.loc[data["variety"]=='Versicolor']

# %%
data_virginica = data.loc[data['variety']=='Virginica']

# %%
plt.plot(data_setosa['sepal_length'],np.zeros_like(data_setosa['sepal_length']),'*')
plt.show()

# %%
plt.plot(data_versicolor['sepal_length'],np.zeros_like(data_versicolor['sepal_length']),'*')
plt.show()

# %%
plt.plot(data_virginica['sepal_length'],np.zeros_like(data_virginica['sepal_length']),'*',)
plt.show()

# %%
plt.plot(data_setosa['sepal_length'],np.zeros_like(data_setosa['sepal_length']),'o')
plt.plot(data_virginica['sepal_length'],np.zeros_like(data_virginica['sepal_length']),'o')
plt.plot(data_versicolor['sepal_length'],np.zeros_like(data_versicolor['sepal_length']),'o')
plt.xlabel('Petal length')
plt.show()

# %% [markdown]
# #  Bivariate Analysis
# * This type of data involves two different variables. The analysis of this type of data deals with causes and relationships and the analysis is done to find out the relationship among the two variables.Example of bivariate data

# %%
sn.FacetGrid(data, hue="variety",size=6).map(plt.scatter,"petal_length",'sepal_width').add_legend();
plt.show()

# %% [markdown]
# # Multivariate Analysis
# * When the data involves three or more variables, it is categorized under multivariate. Example of this type of data is suppose an

# %%
sn.pairplot(data, hue="variety",size=4)
# Out:
# c:\python37\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)
